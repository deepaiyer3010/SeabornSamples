# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
fifa = (pd.read_csv(r'C:\Users\Deepa\Desktop\Python\Data\fifa.csv', 
                    index_col='Date',parse_dates=True))

# %%
fifa.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
fifa.index
# Out:
# DatetimeIndex(['1993-08-08', '1993-09-23', '1993-10-22', '1993-11-19',
#                '1993-12-23', '1994-02-15', '1994-03-15', '1994-04-19',
#                '1994-05-17', '1994-06-14',
#                ...
#                '2017-09-14', '2017-10-16', '2017-11-23', '2017-12-21',
#                '2018-01-18', '2018-02-15', '2018-03-15', '2018-04-12',
#                '2018-05-17', '2018-06-07'],
#               dtype='datetime64[ns]', name='Date', length=286, freq=None)

# %%
fifa.dtypes
# Out:
# ARG    float64
# BRA    float64
# ESP    float64
# FRA    float64
# GER    float64
# ITA    float64
# dtype: object

# %%
plt.figure(figsize=(16,6))

sns.lineplot(data=fifa)

# %%
brazil_rank = fifa.loc['1993-12-23','BRA']

# %%
brazil_rank
# Out:
# 3.0

# %%
spotify = pd.read_csv(r'C:\Users\Deepa\Desktop\Python\Data\spotify.csv',
                     index_col='Date', parse_dates=True)

# %%
spotify.dtypes
# Out:
# Shape of You                  int64
# Despacito                   float64
# Something Just Like This    float64
# HUMBLE.                     float64
# Unforgettable               float64
# dtype: object

# %%
spotify.index
# Out:
# DatetimeIndex(['2017-01-06', '2017-01-07', '2017-01-08', '2017-01-09',
#                '2017-01-10', '2017-01-11', '2017-01-12', '2017-01-13',
#                '2017-01-14', '2017-01-15',
#                ...
#                '2017-12-31', '2018-01-01', '2018-01-02', '2018-01-03',
#                '2018-01-04', '2018-01-05', '2018-01-06', '2018-01-07',
#                '2018-01-08', '2018-01-09'],
#               dtype='datetime64[ns]', name='Date', length=366, freq=None)

# %%
spotify.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
spotify.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
plt.figure(figsize=(16,6))

plt.title("Daily global streams of popular songs from 2017-2018")

sns.lineplot(data=spotify)

# %%
spotify.columns
# Out:
# Index(['Shape of You', 'Despacito', 'Something Just Like This', 'HUMBLE.',
#        'Unforgettable'],
#       dtype='object')

# %%
sns.set(font_scale=2)

sns.set_style("white")

plt.figure(figsize=(16,6))

plt.title("Daily global streams comparision of two songs")

sns.lineplot(data=spotify['Shape of You'], label='Shape of You')

sns.lineplot(data=spotify['Despacito'], label='Despacito')

plt.xlabel('Date')

# %%
museum_data = pd.read_csv(r'C:\Users\Deepa\Desktop\Python\Data\data-for-datavis\museum_visitors.csv' 
                          , index_col='Date', parse_dates=True )

# %%
museum_data.columns
# Out:
# Index(['Avila Adobe', 'Firehouse Museum', 'Chinese American Museum',
#        'America Tropical Interpretive Center'],
#       dtype='object')

# %%
museum_data.index
# Out:
# DatetimeIndex(['2014-01-01', '2014-02-01', '2014-03-01', '2014-04-01',
#                '2014-05-01', '2014-06-01', '2014-07-01', '2014-08-01',
#                '2014-09-01', '2014-10-01', '2014-11-01', '2014-12-01',
#                '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01',
#                '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01',
#                '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01',
#                '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01',
#                '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01',
#                '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01',
#                '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01',
#                '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01',
#                '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01',
#                '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
# ...

# %%
museum_data.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
museum_data.tail()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2018-07-01        23136              4191                     2620
# 2018-08-01        20815              4866                     2409
# 2018-09-01        21020              4956                     2146
# 2018-10-01        19280              4622                     2364
# 2018-11-01        17163              4082                     2385
#
#             America Tropical Interpretive Center
# Date
# 2018-07-01                                  4718
# 2018-08-01                                  3891
# 2018-09-01                                  3180
# 2018-10-01                                  3775
# 2018-11-01                                  4562

# %%
ca_museum_jul18 = museum_data.loc['2018-07-01','Chinese American Museum']
avila_oct18 = (museum_data.loc['2018-10-01','Avila Adobe']-
              museum_data.loc['2018-10-01','Firehouse Museum'])

# %%
ca_museum_jul18
# Out:
# 2620

# %%
avila_oct18
# Out:
# 14658

# %%
sns.set(font_scale=2)

sns.set_style("white")

plt.figure(figsize=(16,6))

plt.title('Museum Visitor comparision from 2014-2018')

sns.lineplot(data=museum_data)

# %%
sns.set(font_scale=2)

sns.set_style("whitegrid")

plt.figure(figsize=(16,6))

plt.title('Museum Visitor for Avila Adobe 2014-2018')

sns.lineplot(data=museum_data['Avila Adobe'])

plt.xlabel('Date')
